# %%
import json
import pandas as pd

# %%
with open('result.json', 'r') as file:
    r = json.load(file)

# %%
r2 = pd.read_json('result.json')

# %%
import seaborn as sns

est_errors = r2['Estimation Error'].dropna()
sns.boxplot(est_errors[est_errors < 5000], native_scale=True)
# Out:
# <Axes: ylabel='Estimation Error'>

# %%
sns.boxplot(est_errors, native_scale=True)
# Out:
# <Axes: ylabel='Estimation Error'>

# %%
sns.distplot(est_errors[est_errors < 5000])
# Out:
# C:\Users\Sudip Barua\AppData\Local\Temp\ipykernel_20936\918268903.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(est_errors[est_errors < 5000])
# <Axes: xlabel='Estimation Error', ylabel='Density'>

# %%
sns.histplot(est_errors[est_errors < 5000], kde=True)

sns.histplot(est_errors, kde=True)
# Out:
# <Axes: xlabel='Estimation Error', ylabel='Count'>

# %%
sns.violinplot(est_errors[est_errors < 5000])
# Out:
# <Axes: ylabel='Estimation Error'>

# %%
sns.violinplot(est_errors)
# Out:
# <Axes: ylabel='Estimation Error'>

# %%
print('Estimation error')
print(f'        Mean: {est_errors.mean()}')
print(f'      Median: {est_errors.median()}')
print(f'         Max: {est_errors.max()}')
print(f'         Min: {est_errors.min()}')
# Out:
# Estimation error
#         Mean: 2823.087907818563
#       Median: 1141.2727093969484
#          Max: 11349.563416630683
#          Min: 7.445275158001866

# %%
r2['Estimation Error'].dropna()
# Out:
# 0         587.218150
# 1         607.275813
# 2        6716.050183
# 3         778.084041
# 4        8217.661876
#             ...
# 31253    6709.450455
# 31254    7812.749473
# 31255    6680.755778
# 31256    8388.913661
# 31258    1341.200468
# Name: Estimation Error, Length: 29518, dtype: float64

# %%
r2['Estimation Error']
# Out:
# 0         587.218150
# 1         607.275813
# 2        6716.050183
# 3         778.084041
# 4        8217.661876
#             ...
# 31254    7812.749473
# 31255    6680.755778
# 31256    8388.913661
# 31257            NaN
# 31258    1341.200468
# Name: Estimation Error, Length: 31259, dtype: float64

# %%
est_er = est_errors[est_errors < 5000]
print('Estimation error')
print(f'        Mean: {est_er.mean()}')
print(f'      Median: {est_er.median()}')
print(f'         Max: {est_er.max()}')
# Out:
# Estimation error
#         Mean: 906.7638756945729
#       Median: 778.3327869900102
#          Max: 4984.711626520024
