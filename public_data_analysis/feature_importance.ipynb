# %%
import sklearn
import pandas as pd

# %%
ds = pd.read_csv('antwerp_ds_weather-data.csv', index_col=0)

# %%
ds
# Out:
#         BS 1  BS 2  BS 3  BS 4  BS 5  BS 6  BS 7  BS 8  BS 9  BS 10  ...  \
# 0       -200  -200  -200  -200  -200  -200  -200  -200  -114   -200  ...
# 1       -200  -200  -200  -200  -200  -200  -200  -200  -200   -200  ...
# 2       -200  -200  -200  -200  -200  -200  -200  -200  -200   -200  ...
# 3       -200  -100  -200  -200  -200  -200  -200  -200  -200   -113  ...
# 4       -200  -106  -107  -200  -200  -200  -200  -200  -200   -200  ...
# ...      ...   ...   ...   ...   ...   ...   ...   ...   ...    ...  ...
# 123523  -200  -103  -106  -200  -200  -200  -200  -200  -200   -200  ...
# 123524  -200  -200  -200  -200  -200  -200  -200  -200  -200   -200  ...
# 123525  -200  -200  -200  -200  -200  -200  -200  -200  -200   -200  ...
# 123526  -200   -97  -200  -200  -200  -200  -200  -200  -200    -92  ...
# 123527   -82  -200  -100  -200  -200  -200  -200  -109  -200   -200  ...
#
#         diffuse_radiation  direct_normal_irradiance  global_tilted_irradiance  \
# ...

# %%
for col in ds.columns:
    print(col)
# Out:
# BS 1
# BS 2
# BS 3
# BS 4
# BS 5
# BS 6
# BS 7
# BS 8
# BS 9
# BS 10
# BS 11
# BS 12
# BS 13
# BS 14
# BS 15
# BS 16
# BS 17
# BS 18
# BS 19
# BS 20
# BS 21
# BS 22
# BS 23
# BS 24
# BS 25
# BS 26
# BS 27
# BS 28
# BS 29
# BS 30
# BS 31
# BS 32
# BS 33
# BS 34
# BS 35
# BS 36
# BS 37
# BS 38
# BS 39
# BS 40
# BS 41
# BS 42
# BS 43
# BS 44
# BS 45
# BS 46
# BS 47
# BS 48
# BS 49
# BS 50
# BS 51
# BS 52
# BS 53
# BS 54
# BS 55
# BS 56
# BS 57
# BS 58
# BS 59
# BS 60
# BS 61
# BS 62
# BS 63
# BS 64
# BS 65
# BS 66
# BS 67
# BS 68
# RX Time
# SF
# HDOP
# Latitude
# Longitude
# Weather param sense time
# date
# temperature_2m
# relative_humidity_2m
# dew_point_2m
# apparent_temperature
# precipitation
# rain
# snowfall
# snow_depth
# weather_code
# pressure_msl
# surface_pressure
# cloud_cover
# cloud_cover_low
# cloud_cover_mid
# cloud_cover_high
# et0_fao_evapotranspiration
# vapour_pressure_deficit
# wind_speed_10m
# wind_speed_100m
# wind_direction_10m
# wind_direction_100m
# ...

# %%
for name, val in ds.nunique().items():
    print(name, '   >>   ', val)
# Out:
# BS 1    >>    62
# BS 2    >>    52
# BS 3    >>    44
# BS 4    >>    39
# BS 5    >>    44
# BS 6    >>    32
# BS 7    >>    54
# BS 8    >>    41
# BS 9    >>    59
# BS 10    >>    54
# BS 11    >>    46
# BS 12    >>    64
# BS 13    >>    52
# BS 14    >>    56
# BS 15    >>    50
# BS 16    >>    23
# BS 17    >>    55
# BS 18    >>    63
# BS 19    >>    50
# BS 20    >>    42
# BS 21    >>    38
# BS 22    >>    31
# BS 23    >>    39
# BS 24    >>    34
# BS 25    >>    44
# BS 26    >>    38
# BS 27    >>    54
# BS 28    >>    45
# BS 29    >>    29
# BS 30    >>    20
# BS 31    >>    38
# BS 32    >>    27
# BS 33    >>    34
# BS 34    >>    31
# BS 35    >>    35
# BS 36    >>    26
# BS 37    >>    28
# BS 38    >>    41
# BS 39    >>    48
# BS 40    >>    36
# BS 41    >>    48
# BS 42    >>    9
# BS 43    >>    15
# BS 44    >>    11
# BS 45    >>    13
# BS 46    >>    14
# BS 47    >>    12
# BS 48    >>    35
# BS 49    >>    27
# BS 50    >>    29
# ...

# %%
ds.nunique()
# Out:
# BS 1                                   62
# BS 2                                   52
# BS 3                                   44
# BS 4                                   39
# BS 5                                   44
#                                     ...
# direct_radiation_instant            19377
# diffuse_radiation_instant           26216
# direct_normal_irradiance_instant    19376
# global_tilted_irradiance_instant    26217
# terrestrial_radiation_instant       28605
# Length: 109, dtype: int64

# %%
ds_1 = ds.drop(columns=['RX Time', 'Weather param sense time', 'date'])

# %%
print(ds_1.columns)
# Out:
# Index(['BS 1', 'BS 2', 'BS 3', 'BS 4', 'BS 5', 'BS 6', 'BS 7', 'BS 8', 'BS 9',
#        'BS 10',
#        ...
#        'diffuse_radiation', 'direct_normal_irradiance',
#        'global_tilted_irradiance', 'terrestrial_radiation',
#        'shortwave_radiation_instant', 'direct_radiation_instant',
#        'diffuse_radiation_instant', 'direct_normal_irradiance_instant',
#        'global_tilted_irradiance_instant', 'terrestrial_radiation_instant'],
#       dtype='object', length=106)

# %%
for col in ds_1.columns:
    print(col)
# Out:
# BS 1
# BS 2
# BS 3
# BS 4
# BS 5
# BS 6
# BS 7
# BS 8
# BS 9
# BS 10
# BS 11
# BS 12
# BS 13
# BS 14
# BS 15
# BS 16
# BS 17
# BS 18
# BS 19
# BS 20
# BS 21
# BS 22
# BS 23
# BS 24
# BS 25
# BS 26
# BS 27
# BS 28
# BS 29
# BS 30
# BS 31
# BS 32
# BS 33
# BS 34
# BS 35
# BS 36
# BS 37
# BS 38
# BS 39
# BS 40
# BS 41
# BS 42
# BS 43
# BS 44
# BS 45
# BS 46
# BS 47
# BS 48
# BS 49
# BS 50
# BS 51
# BS 52
# BS 53
# BS 54
# BS 55
# BS 56
# BS 57
# BS 58
# BS 59
# BS 60
# BS 61
# BS 62
# BS 63
# BS 64
# BS 65
# BS 66
# BS 67
# BS 68
# SF
# HDOP
# Latitude
# Longitude
# temperature_2m
# relative_humidity_2m
# dew_point_2m
# apparent_temperature
# precipitation
# rain
# snowfall
# snow_depth
# weather_code
# pressure_msl
# surface_pressure
# cloud_cover
# cloud_cover_low
# cloud_cover_mid
# cloud_cover_high
# et0_fao_evapotranspiration
# vapour_pressure_deficit
# wind_speed_10m
# wind_speed_100m
# wind_direction_10m
# wind_direction_100m
# wind_gusts_10m
# shortwave_radiation
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

scaler.fit(ds_1)
scaled_data = scaler.transform(ds_1)

# %%
ds_scaled = pd.DataFrame(scaled_data, columns=ds_1.columns)

# %%
ds_scaled
# Out:
#             BS 1      BS 2      BS 3  BS 4  BS 5  BS 6  BS 7      BS 8  \
# 0       0.000000  0.000000  0.000000   0.0   0.0   0.0   0.0  0.000000
# 1       0.000000  0.000000  0.000000   0.0   0.0   0.0   0.0  0.000000
# 2       0.000000  0.000000  0.000000   0.0   0.0   0.0   0.0  0.000000
# 3       0.000000  0.751880  0.000000   0.0   0.0   0.0   0.0  0.000000
# 4       0.000000  0.706767  0.750000   0.0   0.0   0.0   0.0  0.000000
# ...          ...       ...       ...   ...   ...   ...   ...       ...
# 123523  0.000000  0.729323  0.758065   0.0   0.0   0.0   0.0  0.000000
# 123524  0.000000  0.000000  0.000000   0.0   0.0   0.0   0.0  0.000000
# 123525  0.000000  0.000000  0.000000   0.0   0.0   0.0   0.0  0.000000
# 123526  0.000000  0.774436  0.000000   0.0   0.0   0.0   0.0  0.000000
# 123527  0.830986  0.000000  0.806452   0.0   0.0   0.0   0.0  0.722222
#
#             BS 9     BS 10  ...  diffuse_radiation  direct_normal_irradiance  \
# ...

# %%
ds_scaled[['Latitude', 'Longitude']]
# Out:
#         Latitude  Longitude
# 0       0.613177   0.646072
# 1       0.920110   0.594466
# 2       0.332874   0.485177
# 3       0.168809   0.688848
# 4       0.421947   0.581724
# ...          ...        ...
# 123523  0.314356   0.662271
# 123524  0.953015   0.681453
# 123525  0.585782   0.648959
# 123526  0.162152   0.692317
# 123527  0.096801   0.924506
#
# [123528 rows x 2 columns]

# %%
# linear regression feature importance
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot
# define dataset
x = ds_scaled.drop(columns=['Latitude', 'Longitude'])
y = ds_scaled['Latitude']
# define the model
model = LinearRegression()
# fit the model
model.fit(x, y)
# get importance
importance = model.coef_
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
#   Cell In[45], line 18
#     pyplot.show(
#                 ^
# SyntaxError: incomplete input
