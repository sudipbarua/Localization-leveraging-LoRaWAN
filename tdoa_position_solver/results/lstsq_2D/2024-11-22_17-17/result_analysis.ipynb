# %%
import pandas as pd

# %%
r = pd.read_csv('estimated_positions.csv', index_col=0)

# %%
r
# Out:
#             lat        lon       alt
# 0     50.818001  12.943430  0.106532
# 1     50.807017  12.936822  0.079078
# 2     50.806764  12.934902  0.070960
# 3     50.818638  12.917907  0.059649
# 4     50.816403  12.945016  0.116945
# ...         ...        ...       ...
# 1724  50.807249  12.930567  0.048453
# 1725  50.807080  12.937341  0.081863
# 1726  50.818028  12.917467  0.058214
# 1727  50.818827  12.918043  0.060268
# 1728  50.816257  12.945130  0.117830
#
# [1729 rows x 3 columns]

# %%
# Importing native libraries
import sys
sys.path.append('D:/work_dir/Datasets/LoRa_anomaly-detection')
from general_functions import *   # We are going to use the 'map_plot_cartopy' method

# %%
map_plot(r, zoom=13.5)
