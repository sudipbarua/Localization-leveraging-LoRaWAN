# %%
import pandas as pd

# %%
r = pd.read_csv('estimated_positions.csv', index_col=0)

# %%
r
# Out:
#             lat        lon         alt
# 0     50.818001  12.943429  350.106526
# 1     50.807017  12.936821  350.079074
# 2     50.806765  12.934901  350.070957
# 3     50.818638  12.917908  350.059645
# 4     50.816403  12.945015  350.116938
# ...         ...        ...         ...
# 1724  50.807249  12.930567  350.048450
# 1725  50.807080  12.937341  350.081859
# 1726  50.818028  12.917467  350.058211
# 1727  50.818827  12.918044  350.060265
# 1728  50.816257  12.945129  350.117824
#
# [1729 rows x 3 columns]

# %%
# Importing native libraries
import sys
sys.path.append('D:/work_dir/Datasets/LoRa_anomaly-detection')
from general_functions import *   # We are going to use the 'map_plot_cartopy' method

# %%
map_plot(r, zoom=13.5)
