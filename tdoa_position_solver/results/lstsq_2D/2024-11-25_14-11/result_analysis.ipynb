# %%
import pandas as pd

# %%
r = pd.read_csv('estimated_positions.csv', index_col=0)

# %%
r
# Out:
#             lat        lon       alt
# 0     50.821718  12.933585  0.067805
# 1     50.807071  12.937278  0.081532
# 2     50.806402  12.933187  0.068267
# 3     50.817933  12.917419  0.057902
# 4     50.819313  12.943594  0.120020
# ...         ...        ...       ...
# 1724  50.807054  12.937155  0.080885
# 1725  50.807046  12.937101  0.080613
# 1726  50.818149  12.917558  0.058405
# 1727  50.816462  12.916528  0.056806
# 1728  50.816207  12.945171  0.118170
#
# [1729 rows x 3 columns]

# %%
# Importing native libraries
import sys
sys.path.append('D:/work_dir/Datasets/LoRa_anomaly-detection')
from general_functions import *   # We are going to use the 'map_plot_cartopy' method

# %%
map_plot(r, zoom=13.5)
