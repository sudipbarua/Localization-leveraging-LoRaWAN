# %%
import pandas as pd

# %%
r = pd.read_csv('estimated_positions.csv', index_col=0)

# %%
r
# Out:
#            lat        lon       alt
# 0    50.819267  12.938232  0.065938
# 1          NaN        NaN       NaN
# 2          NaN        NaN       NaN
# 3          NaN        NaN       NaN
# 4    50.817758  12.939858  0.067004
# ..         ...        ...       ...
# 506  50.819679  12.918304  0.066748
# 507  50.819072  12.917609  0.066018
# 508  50.822412  12.928778  0.066780
# 509        NaN        NaN       NaN
# 510  50.816282  12.940877  0.068487
#
# [511 rows x 3 columns]

# %%
# Importing native libraries
import sys
sys.path.append('D:/work_dir/Datasets/LoRa_anomaly-detection')
from general_functions import *   # We are going to use the 'map_plot_cartopy' method

# %%
map_plot(r, zoom=13.5)
