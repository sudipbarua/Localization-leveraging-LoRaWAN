# %%
import pandas as pd

# %%
r = pd.read_csv('estimated_positions.csv', index_col=0)

# %%
r
# Out:
#            lat        lon         alt
# 0    50.814376  12.927642  350.000177
# 1    50.811994  12.930234  350.006281
# 2    50.814496  12.927988  350.000167
# 3    50.811997  12.930242  350.006281
# 4    50.811980  12.930199  350.006280
# ..         ...        ...         ...
# 905        NaN        NaN         NaN
# 906        NaN        NaN         NaN
# 907        NaN        NaN         NaN
# 908        NaN        NaN         NaN
# 909        NaN        NaN         NaN
#
# [910 rows x 3 columns]

# %%
# Importing native libraries
import sys
sys.path.append('D:/work_dir/Datasets/LoRa_anomaly-detection')
from general_functions import *   # We are going to use the 'map_plot_cartopy' method

# %%
map_plot(r, zoom=17)
