# %%
import pandas as pd

# %%
r = pd.read_csv('estimated_positions.csv', index_col=0)

# %%
r
# Out:
#            lat        lon         alt
# 0    50.814514  12.927468  350.000292
# 1    50.811126  12.931080  350.012333
# 2    50.814668  12.927925  350.000329
# 3    50.811131  12.931092  350.012333
# 4    50.811106  12.931030  350.012333
# ..         ...        ...         ...
# 905        NaN        NaN         NaN
# 906        NaN        NaN         NaN
# 907        NaN        NaN         NaN
# 908        NaN        NaN         NaN
# 909        NaN        NaN         NaN
#
# [910 rows x 3 columns]

# %%
# Importing native libraries
import sys
sys.path.append('D:/work_dir/Datasets/LoRa_anomaly-detection')
from general_functions import *   # We are going to use the 'map_plot_cartopy' method

# %%
map_plot(r, zoom=17)
