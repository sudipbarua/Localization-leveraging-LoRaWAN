# %%
import pandas as pd

# %%
r = pd.read_csv('estimated_positions.csv', index_col=0)

# %%
r
# Out:
#            lat        lon           alt
# 0    50.814688  12.927353  9.811613e+07
# 1    50.814064  12.928137  3.500000e+02
# 2    50.814064  12.928137  3.500000e+02
# 3    50.814064  12.928137  3.500000e+02
# 4    50.814064  12.928137  3.500000e+02
# ..         ...        ...           ...
# 905        NaN        NaN           NaN
# 906        NaN        NaN           NaN
# 907        NaN        NaN           NaN
# 908        NaN        NaN           NaN
# 909        NaN        NaN           NaN
#
# [910 rows x 3 columns]

# %%
# Importing native libraries
import sys
sys.path.append('D:/work_dir/Datasets/LoRa_anomaly-detection')
from general_functions import *   # We are going to use the 'map_plot_cartopy' method

# %%
map_plot(r)
# map_plot(r, zoom=13.5)
